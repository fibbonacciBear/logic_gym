# %%
import sys

PACKAGE_HOME = "../../alpha_fol_solver"
sys.path.append(f"{PACKAGE_HOME}")

from gym_natural_deduction import FlipWrapper

# %%
axioms = """
Max = Variable("Max")


class yumpus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        

class dumpus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        

class wumpus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        

class impus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        

class timpus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        

class sour(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        
checkp(Text("test2"), comment)
checkp(A(x, Impl(yumpus(x), (dumpus(x)))), given)
checkp(A(x, Impl(dumpus(x), (wumpus(x)))), given)
checkp(A(x, Impl(wumpus(x), (impus(x)))), given)
checkp(A(x, Impl(impus(x), (timpus(x)))), given)
checkp(A(x, Impl(timpus(x), Not(sour(x)))), given)
checkp(yumpus(Max), given)


"""
axioms_list = axioms.strip().split('\n')
axioms_list = [elem if not elem.isspace() else "" for elem in axioms_list]

proof = """
rapply(Ae, 1, Max)
rapply(imple, 7, 6)
rapply(Ae, 2, Max)
rapply(imple, 9, 8)
rapply(Ae, 3, Max)
rapply(imple, 11, 10)
rapply(Ae, 4, Max)
rapply(imple, 13, 12)
rapply(Ae, 5, Max)
rapply(imple, 15, 14)

"""

proof_steps = proof.strip().split('\n')

# %%
# get an instance


wrap = FlipWrapper()

# start

try:
    state = wrap.start(
        axioms_list
    )
    print(state)
except Exception as e:
    print(f"An error occurred: {str(e)}")
    
try:
    for proof_step in proof_steps:
        state = wrap.run_proof_step(proof_step)
        print(state)
except Exception as e:
    print(f"An error occurred: {str(e)}")
    
wrap.terminate()
# Out:
# (0, 'xr', (), ((),), "Text('test2')", 'comment')
# (1, 'xr', (), ((),), 'A(x, Impl(yumpus(x),dumpus(x)))', 'given')
# (2, 'xr', (), ((),), 'A(x, Impl(dumpus(x),wumpus(x)))', 'given')
# (3, 'xr', (), ((),), 'A(x, Impl(wumpus(x),impus(x)))', 'given')
# (4, 'xr', (), ((),), 'A(x, Impl(impus(x),timpus(x)))', 'given')
# (5, 'xr', (), ((),), 'A(x, Impl(timpus(x),Not(sour(x))))', 'given')
# (6, 'xr', (), (('Max',),), 'yumpus(Max)', 'given')
#
# yumpus(Max) -> dumpus(Max)                                    (7)  A-Elimination (1), with Max
#
# dumpus(Max)                                                   (8)  Implication-Elimination (Modus Ponens) (7) (6)
#
# dumpus(Max) -> wumpus(Max)                                    (9)  A-Elimination (2), with Max
#
# wumpus(Max)                                                  (10)  Implication-Elimination (Modus Ponens) (9) (8)
#
# wumpus(Max) -> impus(Max)                                    (11)  A-Elimination (3), with Max
#
# impus(Max)                                                   (12)  Implication-Elimination (Modus Ponens) (11) (10)
#
# impus(Max) -> timpus(Max)                                    (13)  A-Elimination (4), with Max
#
# timpus(Max)                                                  (14)  Implication-Elimination (Modus Ponens) (13) (12)
#
# timpus(Max) -> ~sour(Max)                                    (15)  A-Elimination (5), with Max
#
# ~sour(Max)                                                   (16)  Implication-Elimination (Modus Ponens) (15) (14)
