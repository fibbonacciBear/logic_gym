# %%
import sys

FLIP_HOME = "/Users/akashganesan/anaconda3/envs/drlzh/lib/python3.11/site-packages/flip"

# set sys.path to include the directory containing the module
sys.path.append(f"{FLIP_HOME}")
sys.path.append(f"{FLIP_HOME}/logic")
sys.path.append(f"{FLIP_HOME}/poset")

from fol_session import *

# %%
Max = Variable("Max")


class yumpus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        
class dumpus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        
class wumpus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        
class impus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        
class timpus(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)
        
class sour(Relation):
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)



# axioms = [
#     (Text("test2"), comment),
#     (A(x, Impl(yumpus(x), (dumpus(x)))), given),
#     (A(x, Impl(dumpus(x), (wumpus(x)))), given),
#     (A(x, Impl(wumpus(x), (impus(x)))), given),
#     (A(x, Impl(impus(x), (timpus(x)))), given),
#     (A(x, Impl(timpus(x), Not(sour(x)))), given),
#     (yumpus(Max), given),
# ]

checkp(Text("test2"), comment),
checkp(A(x, Impl(yumpus(x), (dumpus(x)))), given),
checkp(A(x, Impl(dumpus(x), (wumpus(x)))), given),
checkp(A(x, Impl(wumpus(x), (impus(x)))), given),
checkp(A(x, Impl(impus(x), (timpus(x)))), given),
checkp(A(x, Impl(timpus(x), Not(sour(x)))), given),
checkp(yumpus(Max), given),

# check_proof(axioms)
rapply(Ae, 1, Max)
rapply(imple, 7, 6)
rapply(Ae, 2, Max)
rapply(imple, 9, 8)
rapply(Ae, 3, Max)
rapply(imple, 11, 10)
rapply(Ae, 4, Max)
rapply(imple, 13, 12)
rapply(Ae, 5, Max)
rapply(imple, 15, 14)
# Out:
# test2                                                        (23)  Comment
# Ax.(yumpus(x) -> dumpus(x))                                  (24)  Given
# Ax.(dumpus(x) -> wumpus(x))                                  (25)  Given
# Ax.(wumpus(x) -> impus(x))                                   (26)  Given
# Ax.(impus(x) -> timpus(x))                                   (27)  Given
# Ax.(timpus(x) -> ~sour(x))                                   (28)  Given
# yumpus(Max)                                                  (29)  Given
# Jompus(Max) -> Wumpus(Max)                                   (30)  A-Elimination (1), with Max
# Apply()                                                      (31)  Implication-Elimination (Modus Ponens) (7) (6)
# Wumpus(Max) -> Transparent(Max)                              (31)  A-Elimination (2), with Max
# Apply()                                                      (32)  Implication-Elimination (Modus Ponens) (9) (8)
# Wumpus(Max) -> Tumpuses(Max)                                 (32)  A-Elimination (3), with Max
# Apply()                                                      (33)  Implication-Elimination (Modus Ponens) (11) (10)
# Tumpuses(Max) -> Mean(Max)                                   (33)  A-Elimination (4), with Max
# Apply()                                                      (34)  Implication-Elimination (Modus Ponens) (13) (12)
# Tumpuses(Max) -> Vumpuses(Max)                               (34)  A-Elimination (5), with Max
# Apply()                                                      (35)  Implication-Elimination (Modus Ponens) (15) (14)
# 'Fail: Ax.(Rompus(x) -> Liquid(x)) does not match m1 -> m2 with {  }'

# %%
# Predicates
class Jompus(Relation):
    "Does x belong to Jompus?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Fruity(Relation):
    "Is x Fruity?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Wumpus(Relation): 
    "Does x belong to Wumpus?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Transparent(Relation): 
    "Is x transparent?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Tumpuses(Relation): 
    "Does x belong to Tumpuses?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Mean(Relation): 
    "Is x mean?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Vumpuses(Relation): 
    "Does x belong to Vumpuses?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Cold(Relation): 
    "Is x cold?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Yumpus(Relation): 
    "Does x belong to Yumpus?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Orange(Relation): 
    "Is x orange?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Numpus(Relation): 
    "Does x belong to Numpus?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Dull(Relation): 
    "Is x dull?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Dumpus(Relation): 
    "Does x belong to Dumpus?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Shy(Relation): 
    "Is x shy?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Impuses(Relation): 
    "Does x belong to Impuses?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Rompus(Relation): 
    "Does x belong to Rompus?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Liquid(Relation): 
    "Is x liquid?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Zumpus(Relation): 
    "Does x belong to Zumpus?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

# Variables
Alex = Variable("Alex")

# Rules

checkp(A(x, Impl(Jompus(x), (Fruity(x)))), given)
checkp(A(x,Impl(Jompus(x), Wumpus(x))), given)
checkp(A(x,Impl(Wumpus(x), Not(Transparent(x)))), given)
checkp(A(x,Impl(Wumpus(x), Tumpuses(x))), given)
checkp(A(x,Impl(Tumpuses(x), Mean(x))), given)
checkp(A(x,Impl(Tumpuses(x), Vumpuses(x))), given)
checkp(A(x,Impl(Vumpuses(x), Cold(x))), given)
checkp(A(x,Impl(Vumpuses(x), Yumpus(x))), given)
checkp(A(x,Impl(Yumpus(x), Orange(x))), given)
checkp(A(x,Impl(Yumpus(x), Numpus(x))), given)
checkp(A(x,Impl(Numpus(x), Dull(x))), given)
checkp(A(x,Impl(Numpus(x), Dumpus(x))), given)
checkp(A(x,Impl(Dumpus(x), Not(Shy(x)))), given)
checkp(A(x,Impl(Impuses(x), Shy(x))), given)
checkp(A(x,Impl(Dumpus(x), Rompus(x))), given)
checkp(A(x,Impl(Rompus(x), Liquid(x))), given)
checkp(A(x,Impl(Rompus(x), Zumpus(x))), given)
checkp(Tumpuses(Alex), given)


# Goals
checkp(Text("Goal: ~Shy(Alex)"), comment)
checkp(Text("Negative Goal: Shy(Alex)"), comment)



# # Query:
# ~Shy(Alex)
# Out:
# Ax.(Jompus(x) -> Fruity(x))                                  (61)  Given
# Ax.(Jompus(x) -> Wumpus(x))                                  (62)  Given
# Ax.(Wumpus(x) -> ~Transparent(x))                            (63)  Given
# Ax.(Wumpus(x) -> Tumpuses(x))                                (64)  Given
# Ax.(Tumpuses(x) -> Mean(x))                                  (65)  Given
# Ax.(Tumpuses(x) -> Vumpuses(x))                              (66)  Given
# Ax.(Vumpuses(x) -> Cold(x))                                  (67)  Given
# Ax.(Vumpuses(x) -> Yumpus(x))                                (68)  Given
# Ax.(Yumpus(x) -> Orange(x))                                  (69)  Given
# Ax.(Yumpus(x) -> Numpus(x))                                  (70)  Given
# Ax.(Numpus(x) -> Dull(x))                                    (71)  Given
# Ax.(Numpus(x) -> Dumpus(x))                                  (72)  Given
# Ax.(Dumpus(x) -> ~Shy(x))                                    (73)  Given
# Ax.(Impuses(x) -> Shy(x))                                    (74)  Given
# Ax.(Dumpus(x) -> Rompus(x))                                  (75)  Given
# Ax.(Rompus(x) -> Liquid(x))                                  (76)  Given
# Ax.(Rompus(x) -> Zumpus(x))                                  (77)  Given
# Tumpuses(Alex)                                               (78)  Given
# Goal: ~Shy(Alex)                                             (79)  Comment
# Negative Goal: Shy(Alex)                                     (80)  Comment

# %%
# Predicates
class Cat(Relation):
    "Does x belong to Cat?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Feline(Relation):
    "Does x belong to Feline?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Carnivore(Relation):
    "Does x belong to Carnivore?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Herbivorous(Relation):
    "Is x herbivorous?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Snake(Relation):
    "Does x belong to Snake?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class WarmBlooded(Relation):
    "Is x warm-blooded?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Mammal(Relation):
    "Does x belong to Mammal?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Vertebrate(Relation):
    "Does x belong to Vertebrate?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Animal(Relation):
    "Does x belong to Animal?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Multicellular(Relation):
    "Is x multicellular?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

# Variables
Sally = Variable("Sally")

# Rules
checkp(A(x, Impl(Cat(x), Feline(x))), given)
checkp(A(x, Impl(Feline(x), Carnivore(x))), given)
checkp(A(x, Impl(Carnivore(x), Not(Herbivorous(x)))), given)
checkp(A(x, Impl(Snake(x), Not(WarmBlooded(x)))), given)
checkp(A(x, Impl(Carnivore(x), Mammal(x))), given)
checkp(A(x, Impl(Mammal(x), WarmBlooded(x))), given)
checkp(A(x, Impl(Mammal(x), Vertebrate(x))), given)
checkp(A(x, Impl(Vertebrate(x), Animal(x))), given)
checkp(A(x, Impl(Animal(x), Multicellular(x))), given)
checkp(Mammal(Sally), given)

# Goals
checkp(Text("Goal: WarmBlooded(Sally)"), comment)
checkp(Text("Negative Goal: ~WarmBlooded(Sally)"), comment)
# Out:
# Ax.(Cat(x) -> Feline(x))                                     (93)  Given
# Ax.(Feline(x) -> Carnivore(x))                               (94)  Given
# Ax.(Carnivore(x) -> ~Herbivorous(x))                         (95)  Given
# Ax.(Snake(x) -> ~WarmBlooded(x))                             (96)  Given
# Ax.(Carnivore(x) -> Mammal(x))                               (97)  Given
# Ax.(Mammal(x) -> WarmBlooded(x))                             (98)  Given
# Ax.(Mammal(x) -> Vertebrate(x))                              (99)  Given
# Ax.(Vertebrate(x) -> Animal(x))                              (100)  Given
# Ax.(Animal(x) -> Multicellular(x))                           (101)  Given
# Mammal(Sally)                                                (102)  Given
# Goal: WarmBlooded(Sally)                                     (103)  Comment
# Negative Goal: ~WarmBlooded(Sally)                           (104)  Comment
# Mammal(Sally) -> WarmBlooded(Sally)                          (105)  A-Elimination (86), with Sally
# Apply()                                                      (106)  Implication-Elimination (Modus Ponens) (93) (90)
# 'Fail: Ax.(Cat(x) -> Feline(x)) does not match m1 -> m2 with {  }'

# %%
class Cat(Relation):
    "Does x belong to Cat?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Feline(Relation):
    "Is x a Feline?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Carnivore(Relation):
    "Is x a Carnivore?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Herbivorous(Relation):
    "Is x herbivorous?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Snake(Relation):
    "Is x a Snake?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class WarmBlooded(Relation):
    "Is x warm-blooded?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Mammal(Relation):
    "Is x a Mammal?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Vertebrate(Relation):
    "Is x a Vertebrate?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Animal(Relation):
    "Is x an Animal?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Multicellular(Relation):
    "Is x multicellular?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

Sally = Variable("Sally")

checkp(A(x,Impl(Cat(x), Feline(x))), given)
checkp(A(x,Impl(Feline(x), Carnivore(x))), given)
checkp(A(x,Impl(Carnivore(x), Not(Herbivorous(x)))), given)
checkp(A(x,Impl(Snake(x), Not(WarmBlooded(x)))), given)
checkp(A(x,Impl(Carnivore(x), Mammal(x))), given)
checkp(A(x,Impl(Mammal(x), WarmBlooded(x))), given)
checkp(A(x,Impl(Mammal(x), Vertebrate(x))), given)
checkp(A(x,Impl(Vertebrate(x), Animal(x))), given)
checkp(A(x,Impl(Animal(x), Multicellular(x))), given)
checkp(Mammal(Sally), given)

checkp(Text("Goal: WarmBlooded(Sally)"), comment)
checkp(Text("Negative Goal: ~WarmBlooded(Sally)"), comment)
# Out:
# Ax.(Cat(x) -> Feline(x))                                     (109)  Given
# Ax.(Feline(x) -> Carnivore(x))                               (110)  Given
# Ax.(Carnivore(x) -> ~Herbivorous(x))                         (111)  Given
# Ax.(Snake(x) -> ~WarmBlooded(x))                             (112)  Given
# Ax.(Carnivore(x) -> Mammal(x))                               (113)  Given
# Ax.(Mammal(x) -> WarmBlooded(x))                             (114)  Given
# Ax.(Mammal(x) -> Vertebrate(x))                              (115)  Given
# Ax.(Vertebrate(x) -> Animal(x))                              (116)  Given
# Ax.(Animal(x) -> Multicellular(x))                           (117)  Given
# Mammal(Sally)                                                (118)  Given
# Goal: WarmBlooded(Sally)                                     (119)  Comment
# Negative Goal: ~WarmBlooded(Sally)                           (120)  Comment

# %%
# Predicates
class Cat(Relation):
    "Does x belong to Cat?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Feline(Relation):
    "Does x belong to Feline?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Carnivore(Relation):
    "Does x belong to Carnivore?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Herbivorous(Relation):
    "Is x herbivorous?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Snake(Relation):
    "Does x belong to Snake?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class WarmBlooded(Relation):
    "Is x warm-blooded?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Mammal(Relation):
    "Does x belong to Mammal?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Vertebrate(Relation):
    "Does x belong to Vertebrate?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Animal(Relation):
    "Does x belong to Animal?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

class Multicellular(Relation):
    "Is x multicellular?"
    def __init__(self, *args):  # seq of args
        Relation.__init__(self, *args)

# Variables
Sally = Variable("Sally")

# Rules

checkp(A(x, Impl(Cat(x), Feline(x))), given)
checkp(A(x, Impl(Feline(x), Carnivore(x))), given)
checkp(A(x, Impl(Carnivore(x), Not(Herbivorous(x)))), given)
checkp(A(x, Impl(Snake(x), Not(WarmBlooded(x)))), given)
checkp(A(x, Impl(Carnivore(x), Mammal(x))), given)
checkp(A(x, Impl(Mammal(x), WarmBlooded(x))), given)
checkp(A(x, Impl(Mammal(x), Vertebrate(x))), given)
checkp(A(x, Impl(Vertebrate(x), Animal(x))), given)
checkp(A(x, Impl(Animal(x), Multicellular(x))), given)
checkp(Mammal(Sally), given)

# Goals
checkp(Text("Goal: WarmBlooded(Sally)"), comment)
checkp(Text("Negative Goal: ~WarmBlooded(Sally)"), comment)
# Out:
# Ax.(Cat(x) -> Feline(x))                                     (139)  Given
# Ax.(Feline(x) -> Carnivore(x))                               (140)  Given
# Ax.(Carnivore(x) -> ~Herbivorous(x))                         (141)  Given
# Ax.(Snake(x) -> ~WarmBlooded(x))                             (142)  Given
# Ax.(Carnivore(x) -> Mammal(x))                               (143)  Given
# Ax.(Mammal(x) -> WarmBlooded(x))                             (144)  Given
# Ax.(Mammal(x) -> Vertebrate(x))                              (145)  Given
# Ax.(Vertebrate(x) -> Animal(x))                              (146)  Given
# Ax.(Animal(x) -> Multicellular(x))                           (147)  Given
# Mammal(Sally)                                                (148)  Given
# Goal: WarmBlooded(Sally)                                     (149)  Comment
# Negative Goal: ~WarmBlooded(Sally)                           (150)  Comment
